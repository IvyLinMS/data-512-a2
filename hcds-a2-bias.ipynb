# %%
# import libraries needed
import json
import requests

# %% [markdown]
# ## Step 1: Getting the Article and Population Data
#
# In this step, two data set are downloaded.
#
# The Wikipedia politicians by country dataset is downloaded to page_data.csv
# The population data is available in CSV format as WPDS_2020_data.csv. This dataset is drawn from the world population data sheet published by the Population Reference Bureau.

# %% [markdown]
# ## Step 2: Cleaning the Data
#
# Clean up the two data set we got in Step 1
# - page_data.csv dataset contains some page names that start with the string "Template:". which should be removed
# - WPDS_2020_data.csv contains some rows that provide cumulative regional population counts,
# rather than country-level counts. These rows are distinguished by having ALL CAPS values in the 'geography' field
# (e.g. AFRICA, OCEANIA), we will separate the country and sub-region level data into different table, while add a new column in country level data for sub-region name

# %%
import pandas as pd

# %%
page_data = pd.read_csv('page_data.csv')
page_data
# Out:
#                                      page        country     rev_id
# 0      Template:ZambiaProvincialMinisters         Zambia  235107991
# 1                          Bir I of Kanem           Chad  355319463
# 2       Template:Zimbabwe-politician-stub       Zimbabwe  391862046
# 3         Template:Uganda-politician-stub         Uganda  391862070
# 4        Template:Namibia-politician-stub        Namibia  391862409
# ...                                   ...            ...        ...
# 47192                        Yahya Jammeh         Gambia  807482007
# 47193                    Lucius Fairchild  United States  807483006
# 47194                Fahd of Saudi Arabia   Saudi Arabia  807483153
# 47195                   Francis Fessenden  United States  807483270
# 47196                     Ajay Kannoujiya          India  807484325
#
# [47197 rows x 3 columns]

# %%
page_data_clean = page_data.loc[(page_data['page'].apply(lambda r: (r.startswith('Template:') == False)))]
page_data_clean
# Out:
#                                                     page  \
# 1                                         Bir I of Kanem
# 10     Information Minister of the Palestinian Nation...
# 12                                               Yos Por
# 23                                          Julius Gregr
# 24                                          Edvard Gregr
# ...                                                  ...
# 47192                                       Yahya Jammeh
# 47193                                   Lucius Fairchild
# 47194                               Fahd of Saudi Arabia
# 47195                                  Francis Fessenden
# 47196                                    Ajay Kannoujiya
#
#                      country     rev_id
# 1                       Chad  355319463
# 10     Palestinian Territory  393276188
# 12                  Cambodia  393822005
# 23            Czech Republic  395521877
# 24            Czech Republic  395526568
# ...                      ...        ...
# 47192                 Gambia  807482007
# 47193          United States  807483006
# 47194           Saudi Arabia  807483153
# 47195          United States  807483270
# 47196                  India  807484325
#
# [46701 rows x 3 columns]

# %%
wpds_data = pd.read_csv('WPDS_2020_data.csv')
wpds_data
# Out:
#                 FIPS             Name        Type  TimeFrame  Data (M)  \
# 0              WORLD            WORLD       World       2019  7772.850
# 1             AFRICA           AFRICA  Sub-Region       2019  1337.918
# 2    NORTHERN AFRICA  NORTHERN AFRICA  Sub-Region       2019   244.344
# 3                 DZ          Algeria     Country       2019    44.357
# 4                 EG            Egypt     Country       2019   100.803
# ..               ...              ...         ...        ...       ...
# 229               WS            Samoa     Country       2019     0.200
# 230               SB  Solomon Islands     Country       2019     0.715
# 231               TO            Tonga     Country       2019     0.099
# 232               TV           Tuvalu     Country       2019     0.010
# 233               VU          Vanuatu     Country       2019     0.321
#
#      Population
# 0    7772850000
# 1    1337918000
# 2     244344000
# 3      44357000
# 4     100803000
# ..          ...
# 229      200000
# 230      715000
# 231       99000
# 232       10000
# 233      321000
#
# [234 rows x 6 columns]

# %%
wpds_data_clean = wpds_data[['Name', 'Type', 'Population']]
wpds_data_clean
# Out:
#                 Name        Type  Population
# 0              WORLD       World  7772850000
# 1             AFRICA  Sub-Region  1337918000
# 2    NORTHERN AFRICA  Sub-Region   244344000
# 3            Algeria     Country    44357000
# 4              Egypt     Country   100803000
# ..               ...         ...         ...
# 229            Samoa     Country      200000
# 230  Solomon Islands     Country      715000
# 231            Tonga     Country       99000
# 232           Tuvalu     Country       10000
# 233          Vanuatu     Country      321000
#
# [234 rows x 3 columns]

# %%
wpds_data_clean_country = wpds_data_clean.loc[(wpds_data_clean['Type'].apply(lambda r: r =='Country'))]
wpds_data_clean_country
# Out:
#                 Name     Type  Population
# 3            Algeria  Country    44357000
# 4              Egypt  Country   100803000
# 5              Libya  Country     6891000
# 6            Morocco  Country    35952000
# 7              Sudan  Country    43849000
# ..               ...      ...         ...
# 229            Samoa  Country      200000
# 230  Solomon Islands  Country      715000
# 231            Tonga  Country       99000
# 232           Tuvalu  Country       10000
# 233          Vanuatu  Country      321000
#
# [209 rows x 3 columns]

# %%
# Process WPDS data to get Sub-region to country map list
def get_country_region_map():
    country_region_map = {}
    region_name = None
    for index, row in wpds_data_clean.iterrows():
        t = row['Type']
        name = row['Name']
       
        # skip world 
        if (name == 'WORLD'):
            continue
        if (t == 'Sub-Region' and name.isupper()):
            if region_name is None or region_name != name:
                region_name = name
                continue
            
        country_region_map[name] = region_name
    
    return country_region_map


country_region_map = get_country_region_map()
country_region_map
# Out:
# {'Algeria': 'NORTHERN AFRICA',
#  'Egypt': 'NORTHERN AFRICA',
#  'Libya': 'NORTHERN AFRICA',
#  'Morocco': 'NORTHERN AFRICA',
#  'Sudan': 'NORTHERN AFRICA',
#  'Tunisia': 'NORTHERN AFRICA',
#  'Western Sahara': 'NORTHERN AFRICA',
#  'Benin': 'WESTERN AFRICA',
#  'Burkina Faso': 'WESTERN AFRICA',
#  'Cape Verde': 'WESTERN AFRICA',
#  "Cote d'Ivoire": 'WESTERN AFRICA',
#  'Gambia': 'WESTERN AFRICA',
#  'Ghana': 'WESTERN AFRICA',
#  'Guinea': 'WESTERN AFRICA',
#  'Guinea-Bissau': 'WESTERN AFRICA',
#  'Liberia': 'WESTERN AFRICA',
#  'Mali': 'WESTERN AFRICA',
#  'Mauritania': 'WESTERN AFRICA',
#  'Niger': 'WESTERN AFRICA',
#  'Nigeria': 'WESTERN AFRICA',
#  'Senegal': 'WESTERN AFRICA',
#  'Sierra Leone': 'WESTERN AFRICA',
#  'Togo': 'WESTERN AFRICA',
#  'Burundi': 'EASTERN AFRICA',
#  'Comoros': 'EASTERN AFRICA',
#  'Djibouti': 'EASTERN AFRICA',
#  'Eritrea': 'EASTERN AFRICA',
#  'Ethiopia': 'EASTERN AFRICA',
#  'Kenya': 'EASTERN AFRICA',
#  'Madagascar': 'EASTERN AFRICA',
#  'Malawi': 'EASTERN AFRICA',
#  'Mauritius': 'EASTERN AFRICA',
#  'Mayotte': 'EASTERN AFRICA',
#  'Mozambique': 'EASTERN AFRICA',
#  'Reunion': 'EASTERN AFRICA',
#  'Rwanda': 'EASTERN AFRICA',
#  'Seychelles': 'EASTERN AFRICA',
#  'Somalia': 'EASTERN AFRICA',
#  'South Sudan': 'EASTERN AFRICA',
#  'Tanzania': 'EASTERN AFRICA',
#  'Uganda': 'EASTERN AFRICA',
#  'Zambia': 'EASTERN AFRICA',
#  'Zimbabwe': 'EASTERN AFRICA',
#  'Angola': 'MIDDLE AFRICA',
#  'Cameroon': 'MIDDLE AFRICA',
#  'Central African Republic': 'MIDDLE AFRICA',
#  'Chad': 'MIDDLE AFRICA',
#  'Congo': 'MIDDLE AFRICA',
#  'Congo, Dem. Rep.': 'MIDDLE AFRICA',
#  'Equatorial Guinea': 'MIDDLE AFRICA',
#  'Gabon': 'MIDDLE AFRICA',
#  'Sao Tome and Principe': 'MIDDLE AFRICA',
#  'Botswana': 'SOUTHERN AFRICA',
#  'eSwatini': 'SOUTHERN AFRICA',
#  'Lesotho': 'SOUTHERN AFRICA',
#  'Namibia': 'SOUTHERN AFRICA',
#  'South Africa': 'SOUTHERN AFRICA',
#  'Canada': 'NORTHERN AMERICA',
#  'United States': 'NORTHERN AMERICA',
#  'Belize': 'CENTRAL AMERICA',
#  'Costa Rica': 'CENTRAL AMERICA',
#  'El Salvador': 'CENTRAL AMERICA',
#  'Guatemala': 'CENTRAL AMERICA',
#  'Honduras': 'CENTRAL AMERICA',
#  'Mexico': 'CENTRAL AMERICA',
#  'Nicaragua': 'CENTRAL AMERICA',
#  'Panama': 'CENTRAL AMERICA',
#  'Antigua and Barbuda': 'CARIBBEAN',
#  'Bahamas': 'CARIBBEAN',
#  'Barbados': 'CARIBBEAN',
#  'Cuba': 'CARIBBEAN',
#  'Curacao': 'CARIBBEAN',
#  'Dominica': 'CARIBBEAN',
#  'Dominican Republic': 'CARIBBEAN',
#  'Grenada': 'CARIBBEAN',
#  'Guadeloupe': 'CARIBBEAN',
#  'Haiti': 'CARIBBEAN',
#  'Jamaica': 'CARIBBEAN',
#  'Martinique': 'CARIBBEAN',
#  'Puerto Rico': 'CARIBBEAN',
#  'St. Kitts-Nevis': 'CARIBBEAN',
#  'Saint Lucia': 'CARIBBEAN',
#  'St. Vincent and the Grenadines': 'CARIBBEAN',
#  'Trinidad and Tobago': 'CARIBBEAN',
#  'Argentina': 'SOUTH AMERICA',
#  'Bolivia': 'SOUTH AMERICA',
#  'Brazil': 'SOUTH AMERICA',
#  'Chile': 'SOUTH AMERICA',
#  'Colombia': 'SOUTH AMERICA',
#  'Ecuador': 'SOUTH AMERICA',
#  'French Guiana': 'SOUTH AMERICA',
#  'Guyana': 'SOUTH AMERICA',
#  'Paraguay': 'SOUTH AMERICA',
#  'Peru': 'SOUTH AMERICA',
#  'Suriname': 'SOUTH AMERICA',
#  'Uruguay': 'SOUTH AMERICA',
#  'Venezuela': 'SOUTH AMERICA',
#  'Armenia': 'WESTERN ASIA',
#  'Azerbaijan': 'WESTERN ASIA',
#  'Bahrain': 'WESTERN ASIA',
#  'Cyprus': 'WESTERN ASIA',
#  'Georgia': 'WESTERN ASIA',
#  'Iraq': 'WESTERN ASIA',
#  'Israel': 'WESTERN ASIA',
#  'Jordan': 'WESTERN ASIA',
#  'Kuwait': 'WESTERN ASIA',
#  'Lebanon': 'WESTERN ASIA',
#  'Oman': 'WESTERN ASIA',
#  'Palestinian Territory': 'WESTERN ASIA',
#  'Qatar': 'WESTERN ASIA',
#  'Saudi Arabia': 'WESTERN ASIA',
#  'Syria': 'WESTERN ASIA',
#  'Turkey': 'WESTERN ASIA',
#  'United Arab Emirates': 'WESTERN ASIA',
#  'Yemen': 'WESTERN ASIA',
#  'Kazakhstan': 'CENTRAL ASIA',
#  'Kyrgyzstan': 'CENTRAL ASIA',
#  'Tajikistan': 'CENTRAL ASIA',
#  'Turkmenistan': 'CENTRAL ASIA',
#  'Uzbekistan': 'CENTRAL ASIA',
#  'Afghanistan': 'SOUTH ASIA',
#  'Bangladesh': 'SOUTH ASIA',
#  'Bhutan': 'SOUTH ASIA',
#  'India': 'SOUTH ASIA',
#  'Iran': 'SOUTH ASIA',
#  'Maldives': 'SOUTH ASIA',
#  'Nepal': 'SOUTH ASIA',
#  'Pakistan': 'SOUTH ASIA',
#  'Sri Lanka': 'SOUTH ASIA',
#  'Brunei': 'SOUTHEAST ASIA',
#  'Cambodia': 'SOUTHEAST ASIA',
#  'Indonesia': 'SOUTHEAST ASIA',
#  'Laos': 'SOUTHEAST ASIA',
#  'Malaysia': 'SOUTHEAST ASIA',
#  'Myanmar': 'SOUTHEAST ASIA',
#  'Philippines': 'SOUTHEAST ASIA',
#  'Singapore': 'SOUTHEAST ASIA',
#  'Thailand': 'SOUTHEAST ASIA',
#  'Timor-Leste': 'SOUTHEAST ASIA',
#  'Vietnam': 'SOUTHEAST ASIA',
#  'China': 'EAST ASIA',
#  'China, Hong Kong SAR': 'EAST ASIA',
#  'China, Macao SAR': 'EAST ASIA',
#  'Japan': 'EAST ASIA',
#  'Korea, North': 'EAST ASIA',
#  'Korea, South': 'EAST ASIA',
#  'Mongolia': 'EAST ASIA',
#  'Taiwan': 'EAST ASIA',
#  'Channel Islands': 'NORTHERN EUROPE',
#  'Denmark': 'NORTHERN EUROPE',
#  'Estonia': 'NORTHERN EUROPE',
#  'Finland': 'NORTHERN EUROPE',
#  'Iceland': 'NORTHERN EUROPE',
#  'Ireland': 'NORTHERN EUROPE',
#  'Latvia': 'NORTHERN EUROPE',
#  'Lithuania': 'NORTHERN EUROPE',
#  'Norway': 'NORTHERN EUROPE',
#  'Sweden': 'NORTHERN EUROPE',
#  'United Kingdom': 'NORTHERN EUROPE',
#  'Austria': 'WESTERN EUROPE',
#  'Belgium': 'WESTERN EUROPE',
#  'France': 'WESTERN EUROPE',
#  'Germany': 'WESTERN EUROPE',
#  'Liechtenstein': 'WESTERN EUROPE',
#  'Luxembourg': 'WESTERN EUROPE',
#  'Monaco': 'WESTERN EUROPE',
#  'Netherlands': 'WESTERN EUROPE',
#  'Switzerland': 'WESTERN EUROPE',
#  'Belarus': 'EASTERN EUROPE',
#  'Bulgaria': 'EASTERN EUROPE',
#  'Czechia': 'EASTERN EUROPE',
#  'Hungary': 'EASTERN EUROPE',
#  'Moldova': 'EASTERN EUROPE',
#  'Poland': 'EASTERN EUROPE',
#  'Romania': 'EASTERN EUROPE',
#  'Russia': 'EASTERN EUROPE',
#  'Slovakia': 'EASTERN EUROPE',
#  'Ukraine': 'EASTERN EUROPE',
#  'Albania': 'SOUTHERN EUROPE',
#  'Andorra': 'SOUTHERN EUROPE',
#  'Bosnia-Herzegovina': 'SOUTHERN EUROPE',
#  'Croatia': 'SOUTHERN EUROPE',
#  'Greece': 'SOUTHERN EUROPE',
#  'Italy': 'SOUTHERN EUROPE',
#  'Kosovo': 'SOUTHERN EUROPE',
#  'Malta': 'SOUTHERN EUROPE',
#  'Montenegro': 'SOUTHERN EUROPE',
#  'North Macedonia': 'SOUTHERN EUROPE',
#  'Portugal': 'SOUTHERN EUROPE',
#  'San Marino': 'SOUTHERN EUROPE',
#  'Serbia': 'SOUTHERN EUROPE',
#  'Slovenia': 'SOUTHERN EUROPE',
#  'Spain': 'SOUTHERN EUROPE',
#  'Australia': 'OCEANIA',
#  'Federated States of Micronesia': 'OCEANIA',
#  'Fiji': 'OCEANIA',
#  'French Polynesia': 'OCEANIA',
#  'Guam': 'OCEANIA',
#  'Kiribati': 'OCEANIA',
#  'Marshall Islands': 'OCEANIA',
#  'Nauru': 'OCEANIA',
#  'New Caledonia': 'OCEANIA',
#  'New Zealand': 'OCEANIA',
#  'Palau': 'OCEANIA',
#  'Papua New Guinea': 'OCEANIA',
#  'Samoa': 'OCEANIA',
#  'Solomon Islands': 'OCEANIA',
#  'Tonga': 'OCEANIA',
#  'Tuvalu': 'OCEANIA',
#  'Vanuatu': 'OCEANIA'}

# %%
wpds_data_clean_country_with_region = wpds_data_clean_country.copy()
wpds_data_clean_country_with_region['sub_region'] = wpds_data_clean_country_with_region['Name'].map(country_region_map)
wpds_data_clean_country_with_region
# Out:
#                 Name     Type  Population       sub_region
# 3            Algeria  Country    44357000  NORTHERN AFRICA
# 4              Egypt  Country   100803000  NORTHERN AFRICA
# 5              Libya  Country     6891000  NORTHERN AFRICA
# 6            Morocco  Country    35952000  NORTHERN AFRICA
# 7              Sudan  Country    43849000  NORTHERN AFRICA
# ..               ...      ...         ...              ...
# 229            Samoa  Country      200000          OCEANIA
# 230  Solomon Islands  Country      715000          OCEANIA
# 231            Tonga  Country       99000          OCEANIA
# 232           Tuvalu  Country       10000          OCEANIA
# 233          Vanuatu  Country      321000          OCEANIA
#
# [209 rows x 4 columns]

# %% [markdown]
# ## Step 3: Getting Article Quality Predictions
#
# In this step, we will try to get the predicted quality category for each article in the Wikipedia dataset.
# To support easy repro and avoid install the ORES client, we will use the API call to get the page quality prediction results
#
# Pages that cannot get prediction result are saved in page_data_with_no_quality.csv file

# %%
# Use the batch API to get the page quality prediction to speed up
api_endpoint = "https://ores.wikimedia.org/v3/scores/enwiki?models=articlequality&revids={rev_ids}"

# %%
headers = {
    'User-Agent': 'https://github.com/IvyLinMS',
    'From': 'ivylin@uw.edu'
}

# %%
def api_call(rev_ids):
    call = requests.get(api_endpoint.format(rev_ids = rev_ids), headers=headers)
    response = call.json()
    return response



def get_page_quality_prediction():
    page_quality_results = {}
    
    # split list into even size chunks for speedy process
    def chunks(lst, n):
        for i in range(0, len(lst), n):
            yield lst[i:i + n]
    # API allow max 50 in a batch
    batch_size = 50
    for rev_id_chunks in chunks(page_data_clean['rev_id'], batch_size):
        rev_ids = '|'.join(str(rev_id) for rev_id in rev_id_chunks)
        print('.', end =' ')
        result = api_call(rev_ids)
        for key in result['enwiki']['scores']:
            if 'score' in result['enwiki']['scores'][key]['articlequality']:
                page_quality_results[key] = result['enwiki']['scores'][key]['articlequality']['score']['prediction']
            else:
                page_quality_results[key] = 'N/A'
    return page_quality_results

# %%
page_quality_results = get_page_quality_prediction()
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %%
page_data_with_quality = page_data_clean.copy()
page_data_with_quality['article_quality_est'] = page_data_with_quality['rev_id'].astype(str).map(page_quality_results)
page_data_with_quality
# Out:
#                                                     page  \
# 1                                         Bir I of Kanem
# 10     Information Minister of the Palestinian Nation...
# 12                                               Yos Por
# 23                                          Julius Gregr
# 24                                          Edvard Gregr
# ...                                                  ...
# 47192                                       Yahya Jammeh
# 47193                                   Lucius Fairchild
# 47194                               Fahd of Saudi Arabia
# 47195                                  Francis Fessenden
# 47196                                    Ajay Kannoujiya
#
#                      country     rev_id article_quality_est
# 1                       Chad  355319463                Stub
# 10     Palestinian Territory  393276188                Stub
# 12                  Cambodia  393822005                Stub
# 23            Czech Republic  395521877                Stub
# 24            Czech Republic  395526568                Stub
# ...                      ...        ...                 ...
# 47192                 Gambia  807482007                  GA
# 47193          United States  807483006                   C
# 47194           Saudi Arabia  807483153                  GA
# 47195          United States  807483270                   C
# 47196                  India  807484325                 N/A
#
# [46701 rows x 4 columns]

# %%
page_data_with_quality_cleaned = page_data_with_quality.loc[page_data_with_quality['article_quality_est'].apply(lambda r: (r != 'N/A'))]
page_data_with_quality_cleaned
# Out:
#                                                     page  \
# 1                                         Bir I of Kanem
# 10     Information Minister of the Palestinian Nation...
# 12                                               Yos Por
# 23                                          Julius Gregr
# 24                                          Edvard Gregr
# ...                                                  ...
# 47191                                        Hal Bidlack
# 47192                                       Yahya Jammeh
# 47193                                   Lucius Fairchild
# 47194                               Fahd of Saudi Arabia
# 47195                                  Francis Fessenden
#
#                      country     rev_id article_quality_est
# 1                       Chad  355319463                Stub
# 10     Palestinian Territory  393276188                Stub
# 12                  Cambodia  393822005                Stub
# 23            Czech Republic  395521877                Stub
# 24            Czech Republic  395526568                Stub
# ...                      ...        ...                 ...
# 47191          United States  807481636                   C
# 47192                 Gambia  807482007                  GA
# 47193          United States  807483006                   C
# 47194           Saudi Arabia  807483153                  GA
# 47195          United States  807483270                   C
#
# [46425 rows x 4 columns]

# %%
# Pages that cannot get prediction result are saved in page_data_with_no_quality.csv file
page_data_with_no_quality = page_data_with_quality.loc[page_data_with_quality['article_quality_est'].apply(lambda r: (r == 'N/A'))]
page_data_with_no_quality.to_csv('page_data_with_no_quality.csv', index=False) 
page_data_with_no_quality
# Out:
#                                  page         country     rev_id  \
# 126     List of politicians in Poland          Poland  516633096
# 222                        Tingtingru         Vanuatu  550682925
# 330                       Daud Arsala     Afghanistan  627547024
# 359    Book:Two Political Biographies           India  636911471
# 514                       Dilaver Bey          Turkey  669987106
# ...                               ...             ...        ...
# 46782          John Rose (Trotskyist)  United Kingdom  807336308
# 46862                  Jalal Movaghar            Iran  807367030
# 46863                 Mohsen Movaghar            Iran  807367166
# 47182                  King Gutierrez     Philippines  807479587
# 47196                 Ajay Kannoujiya           India  807484325
#
#       article_quality_est
# 126                   N/A
# 222                   N/A
# 330                   N/A
# 359                   N/A
# 514                   N/A
# ...                   ...
# 46782                 N/A
# 46862                 N/A
# 46863                 N/A
# 47182                 N/A
# 47196                 N/A
#
# [276 rows x 4 columns]

# %% [markdown]
# ## Step 4: Combining the Datasets
#
# In this step, we will merge the wikipedia data and population data together use the contry name as key,
#  - Rows that do not have matching data, and output them to a CSV file called: wp_wpds_countries-no_match.csv
#  - remaining data into a single CSV file called: wp_wpds_politicians_by_country.csv with columns country, article_name, revision_id, article_quality_est, population

# %%
merged_data = page_data_with_quality_cleaned.merge(wpds_data_clean_country_with_region,how='outer',left_on=['country'],right_on=['Name'])
merged_data
# Out:
#                        page country       rev_id article_quality_est  \
# 0            Bir I of Kanem    Chad  355319463.0                Stub
# 1      Abdullah II of Kanem    Chad  498683267.0                Stub
# 2       Salmama II of Kanem    Chad  565745353.0                Stub
# 3           Kuri I of Kanem    Chad  565745365.0                Stub
# 4       Mohammed I of Kanem    Chad  565745375.0                Stub
# ...                     ...     ...          ...                 ...
# 46446                   NaN     NaN          NaN                 NaN
# 46447                   NaN     NaN          NaN                 NaN
# 46448                   NaN     NaN          NaN                 NaN
# 46449                   NaN     NaN          NaN                 NaN
# 46450                   NaN     NaN          NaN                 NaN
#
#                    Name     Type  Population     sub_region
# 0                  Chad  Country  16877000.0  MIDDLE AFRICA
# 1                  Chad  Country  16877000.0  MIDDLE AFRICA
# 2                  Chad  Country  16877000.0  MIDDLE AFRICA
# 3                  Chad  Country  16877000.0  MIDDLE AFRICA
# 4                  Chad  Country  16877000.0  MIDDLE AFRICA
# ...                 ...      ...         ...            ...
# 46446  French Polynesia  Country    280000.0        OCEANIA
# 46447              Guam  Country    175000.0        OCEANIA
# 46448     New Caledonia  Country    295000.0        OCEANIA
# 46449             Palau  Country     18000.0        OCEANIA
# 46450             Samoa  Country    200000.0        OCEANIA
#
# [46451 rows x 8 columns]

# %%
# get the unmatched data
unmatched_data = merged_data.loc[merged_data['country'].isna() | merged_data['Name'].isna()]
unmatched_data.to_csv('wp_wpds_countries-no_match.csv', index=False) 
unmatched_data
# Out:
#                  page         country       rev_id article_quality_est  \
# 488      Julius Gregr  Czech Republic  395521877.0                Stub
# 489      Edvard Gregr  Czech Republic  395526568.0                Stub
# 490    Miroslav Poche  Czech Republic  672862914.0                Stub
# 491     Vojtěch Mynář  Czech Republic  673008587.0                Stub
# 492      Jan Malypetr  Czech Republic  704424304.0                Stub
# ...               ...             ...          ...                 ...
# 46446             NaN             NaN          NaN                 NaN
# 46447             NaN             NaN          NaN                 NaN
# 46448             NaN             NaN          NaN                 NaN
# 46449             NaN             NaN          NaN                 NaN
# 46450             NaN             NaN          NaN                 NaN
#
#                    Name     Type  Population sub_region
# 488                 NaN      NaN         NaN        NaN
# 489                 NaN      NaN         NaN        NaN
# 490                 NaN      NaN         NaN        NaN
# 491                 NaN      NaN         NaN        NaN
# 492                 NaN      NaN         NaN        NaN
# ...                 ...      ...         ...        ...
# 46446  French Polynesia  Country    280000.0    OCEANIA
# 46447              Guam  Country    175000.0    OCEANIA
# 46448     New Caledonia  Country    295000.0    OCEANIA
# 46449             Palau  Country     18000.0    OCEANIA
# 46450             Samoa  Country    200000.0    OCEANIA
#
# [1883 rows x 8 columns]

# %%
matched_data = merged_data.loc[(merged_data['country'].notna()) & (merged_data['Name'].notna())]
matched_data
# Out:
#                        page     country       rev_id article_quality_est  \
# 0            Bir I of Kanem        Chad  355319463.0                Stub
# 1      Abdullah II of Kanem        Chad  498683267.0                Stub
# 2       Salmama II of Kanem        Chad  565745353.0                Stub
# 3           Kuri I of Kanem        Chad  565745365.0                Stub
# 4       Mohammed I of Kanem        Chad  565745375.0                Stub
# ...                     ...         ...          ...                 ...
# 46414            Rita Sinon  Seychelles  800323154.0                Stub
# 46415      Sylvette Frichot  Seychelles  800323798.0                Stub
# 46416          May De Silva  Seychelles  800969960.0               Start
# 46417       Vincent Meriton  Seychelles  802051093.0                Stub
# 46418   Marie-Louise Potter  Seychelles  804209620.0                Stub
#
#              Name     Type  Population      sub_region
# 0            Chad  Country  16877000.0   MIDDLE AFRICA
# 1            Chad  Country  16877000.0   MIDDLE AFRICA
# 2            Chad  Country  16877000.0   MIDDLE AFRICA
# 3            Chad  Country  16877000.0   MIDDLE AFRICA
# 4            Chad  Country  16877000.0   MIDDLE AFRICA
# ...           ...      ...         ...             ...
# 46414  Seychelles  Country     98000.0  EASTERN AFRICA
# 46415  Seychelles  Country     98000.0  EASTERN AFRICA
# 46416  Seychelles  Country     98000.0  EASTERN AFRICA
# 46417  Seychelles  Country     98000.0  EASTERN AFRICA
# 46418  Seychelles  Country     98000.0  EASTERN AFRICA
#
# [44568 rows x 8 columns]

# %%
matched_data_renamed = matched_data.rename(columns={'page': 'article_name', 'rev_id': 'revision_id', 'Population': 'population'})
matched_data_renamed
# Out:
#                article_name     country  revision_id article_quality_est  \
# 0            Bir I of Kanem        Chad  355319463.0                Stub
# 1      Abdullah II of Kanem        Chad  498683267.0                Stub
# 2       Salmama II of Kanem        Chad  565745353.0                Stub
# 3           Kuri I of Kanem        Chad  565745365.0                Stub
# 4       Mohammed I of Kanem        Chad  565745375.0                Stub
# ...                     ...         ...          ...                 ...
# 46414            Rita Sinon  Seychelles  800323154.0                Stub
# 46415      Sylvette Frichot  Seychelles  800323798.0                Stub
# 46416          May De Silva  Seychelles  800969960.0               Start
# 46417       Vincent Meriton  Seychelles  802051093.0                Stub
# 46418   Marie-Louise Potter  Seychelles  804209620.0                Stub
#
#              Name     Type  population      sub_region
# 0            Chad  Country  16877000.0   MIDDLE AFRICA
# 1            Chad  Country  16877000.0   MIDDLE AFRICA
# 2            Chad  Country  16877000.0   MIDDLE AFRICA
# 3            Chad  Country  16877000.0   MIDDLE AFRICA
# 4            Chad  Country  16877000.0   MIDDLE AFRICA
# ...           ...      ...         ...             ...
# 46414  Seychelles  Country     98000.0  EASTERN AFRICA
# 46415  Seychelles  Country     98000.0  EASTERN AFRICA
# 46416  Seychelles  Country     98000.0  EASTERN AFRICA
# 46417  Seychelles  Country     98000.0  EASTERN AFRICA
# 46418  Seychelles  Country     98000.0  EASTERN AFRICA
#
# [44568 rows x 8 columns]

# %%
# generate the data in required format
politicians_by_country_data = pd.concat( [matched_data_renamed['country'], 
                         matched_data_renamed['article_name'],
                         matched_data_renamed['revision_id'],
                         matched_data_renamed['article_quality_est'],
                         matched_data_renamed['population'],
                        ], axis=1)
politicians_by_country_data
# Out:
#           country          article_name  revision_id article_quality_est  \
# 0            Chad        Bir I of Kanem  355319463.0                Stub
# 1            Chad  Abdullah II of Kanem  498683267.0                Stub
# 2            Chad   Salmama II of Kanem  565745353.0                Stub
# 3            Chad       Kuri I of Kanem  565745365.0                Stub
# 4            Chad   Mohammed I of Kanem  565745375.0                Stub
# ...           ...                   ...          ...                 ...
# 46414  Seychelles            Rita Sinon  800323154.0                Stub
# 46415  Seychelles      Sylvette Frichot  800323798.0                Stub
# 46416  Seychelles          May De Silva  800969960.0               Start
# 46417  Seychelles       Vincent Meriton  802051093.0                Stub
# 46418  Seychelles   Marie-Louise Potter  804209620.0                Stub
#
#        population
# 0      16877000.0
# 1      16877000.0
# 2      16877000.0
# 3      16877000.0
# 4      16877000.0
# ...           ...
# 46414     98000.0
# 46415     98000.0
# 46416     98000.0
# 46417     98000.0
# 46418     98000.0
#
# [44568 rows x 5 columns]

# %%
politicians_by_country_data.to_csv('wp_wpds_politicians_by_country.csv', index=False)

# %% [markdown]
# ## Step 5: Analysis
#
# In this step, we will get the country and sub region level article per population and high quality article percetage

# %%
# get aggregate data per country
country_article_count_temp = matched_data_renamed.groupby('country').agg({'article_name':'count'})
country_article_count = country_article_count_temp.rename(columns={'article_name': 'article_count'})
country_article_count
# Out:
#              article_count
# country
# Afghanistan            319
# Albania                456
# Algeria                116
# Andorra                 34
# Angola                 106
# ...                    ...
# Venezuela              130
# Vietnam                187
# Yemen                  116
# Zambia                  25
# Zimbabwe               163
#
# [183 rows x 1 columns]

# %%
country_population = matched_data_renamed.groupby('country').agg({'population':'mean'})
country_population
# Out:
#              population
# country
# Afghanistan  38928000.0
# Albania       2838000.0
# Algeria      44357000.0
# Andorra         82000.0
# Angola       32522000.0
# ...                 ...
# Venezuela    28645000.0
# Vietnam      96209000.0
# Yemen        29826000.0
# Zambia       18384000.0
# Zimbabwe     14863000.0
#
# [183 rows x 1 columns]

# %%
high_quality_article_data = matched_data_renamed.loc[(matched_data_renamed['article_quality_est'].apply(lambda r: r == 'FA' or r =='GA'))]
high_quality_article_data
# Out:
#                            article_name                country  revision_id  \
# 82                        Hissène Habré                   Chad  803166806.0
# 199                     Abdullah Rimawi  Palestinian Territory  788953220.0
# 204                      Khalida Jarrar  Palestinian Territory  791881528.0
# 218                        Ahmed Yassin  Palestinian Territory  797122322.0
# 225                    Marwan Barghouti  Palestinian Territory  798913975.0
# ...                                 ...                    ...          ...
# 46021               Mohammad bin Salman           Saudi Arabia  807463170.0
# 46022              Fahd of Saudi Arabia           Saudi Arabia  807483153.0
# 46050  Jack Warner (football executive)    Trinidad and Tobago  805253461.0
# 46121                   Eugenia Charles               Dominica  802175384.0
# 46230            President of Mauritius              Mauritius  784515275.0
#
#       article_quality_est                   Name     Type  population  \
# 82                     GA                   Chad  Country  16877000.0
# 199                    GA  Palestinian Territory  Country   5008000.0
# 204                    GA  Palestinian Territory  Country   5008000.0
# 218                    GA  Palestinian Territory  Country   5008000.0
# 225                    GA  Palestinian Territory  Country   5008000.0
# ...                   ...                    ...      ...         ...
# 46021                  GA           Saudi Arabia  Country  35041000.0
# 46022                  GA           Saudi Arabia  Country  35041000.0
# 46050                  GA    Trinidad and Tobago  Country   1369000.0
# 46121                  GA               Dominica  Country     72000.0
# 46230                  GA              Mauritius  Country   1265000.0
#
#            sub_region
# 82      MIDDLE AFRICA
# 199      WESTERN ASIA
# 204      WESTERN ASIA
# 218      WESTERN ASIA
# 225      WESTERN ASIA
# ...               ...
# 46021    WESTERN ASIA
# 46022    WESTERN ASIA
# 46050       CARIBBEAN
# 46121       CARIBBEAN
# 46230  EASTERN AFRICA
#
# [1028 rows x 8 columns]

# %%
country_high_quality_article_count_temp = high_quality_article_data.groupby('country').agg({'article_name':'count'})
country_high_quality_article_count = country_high_quality_article_count_temp.rename(columns={'article_name': 'high_quality_article_count'})
country_high_quality_article_count
# Out:
#              high_quality_article_count
# country
# Afghanistan                          13
# Albania                               3
# Algeria                               2
# Argentina                            16
# Armenia                               5
# ...                                 ...
# Vanuatu                               3
# Venezuela                             3
# Vietnam                              13
# Yemen                                 3
# Zimbabwe                              2
#
# [146 rows x 1 columns]

# %%
# join these data
country_merged_aggregate_data_intermediate = country_article_count.merge(country_population,how='left',left_on=['country'],right_on=['country'])
country_merged_aggregate_data_intermediate
# Out:
#              article_count  population
# country
# Afghanistan            319  38928000.0
# Albania                456   2838000.0
# Algeria                116  44357000.0
# Andorra                 34     82000.0
# Angola                 106  32522000.0
# ...                    ...         ...
# Venezuela              130  28645000.0
# Vietnam                187  96209000.0
# Yemen                  116  29826000.0
# Zambia                  25  18384000.0
# Zimbabwe               163  14863000.0
#
# [183 rows x 2 columns]

# %%
country_merged_aggregate_data =  country_merged_aggregate_data_intermediate.merge(country_high_quality_article_count,how='left',left_on=['country'],right_on=['country'])
country_merged_aggregate_data
# Out:
#              article_count  population  high_quality_article_count
# country
# Afghanistan            319  38928000.0                        13.0
# Albania                456   2838000.0                         3.0
# Algeria                116  44357000.0                         2.0
# Andorra                 34     82000.0                         NaN
# Angola                 106  32522000.0                         NaN
# ...                    ...         ...                         ...
# Venezuela              130  28645000.0                         3.0
# Vietnam                187  96209000.0                        13.0
# Yemen                  116  29826000.0                         3.0
# Zambia                  25  18384000.0                         NaN
# Zimbabwe               163  14863000.0                         2.0
#
# [183 rows x 3 columns]

# %%
country_merged_aggregate_data.fillna(0, inplace=True)

# %%
# Calculate the percentage
country_merged_aggregate_data['articles_per_population'] = country_merged_aggregate_data['article_count'].astype('int64') / country_merged_aggregate_data['population'].astype('int64') * 100
country_merged_aggregate_data['high_quality_article_percentage'] = country_merged_aggregate_data['high_quality_article_count'].astype('int64') / country_merged_aggregate_data['article_count'].astype('int64') * 100

country_merged_aggregate_data
# Out:
#              article_count  population  high_quality_article_count  \
# country
# Afghanistan            319  38928000.0                        13.0
# Albania                456   2838000.0                         3.0
# Algeria                116  44357000.0                         2.0
# Andorra                 34     82000.0                         0.0
# Angola                 106  32522000.0                         0.0
# ...                    ...         ...                         ...
# Venezuela              130  28645000.0                         3.0
# Vietnam                187  96209000.0                        13.0
# Yemen                  116  29826000.0                         3.0
# Zambia                  25  18384000.0                         0.0
# Zimbabwe               163  14863000.0                         2.0
#
#              articles_per_population  high_quality_article_percentage
# country
# Afghanistan                 0.000819                         4.075235
# Albania                     0.016068                         0.657895
# Algeria                     0.000262                         1.724138
# Andorra                     0.041463                         0.000000
# Angola                      0.000326                         0.000000
# ...                              ...                              ...
# Venezuela                   0.000454                         2.307692
# Vietnam                     0.000194                         6.951872
# Yemen                       0.000389                         2.586207
# Zambia                      0.000136                         0.000000
# Zimbabwe                    0.001097                         1.226994
#
# [183 rows x 5 columns]

# %%
# region level data
region_article_count_temp = matched_data_renamed.groupby('sub_region').agg({'article_name':'count'})
region_article_count = region_article_count_temp.rename(columns={'article_name': 'article_count'})
region_article_count
# Out:
#                   article_count
# sub_region
# CARIBBEAN                   695
# CENTRAL AMERICA            1543
# CENTRAL ASIA                245
# EAST ASIA                  2473
# EASTERN AFRICA             2502
# EASTERN EUROPE             3732
# MIDDLE AFRICA               665
# NORTHERN AFRICA             899
# NORTHERN AMERICA           1901
# NORTHERN EUROPE            3763
# OCEANIA                    3126
# SOUTH AMERICA              3032
# SOUTH ASIA                 4366
# SOUTHEAST ASIA             2020
# SOUTHERN AFRICA             634
# SOUTHERN EUROPE            3710
# WESTERN AFRICA             2139
# WESTERN ASIA               2563
# WESTERN EUROPE             4560

# %%
region_high_quality_article_count_temp = high_quality_article_data.groupby('sub_region').agg({'article_name':'count'})
region_high_quality_article_count = region_high_quality_article_count_temp.rename(columns={'article_name': 'high_quality_article_count'})
region_high_quality_article_count
# Out:
#                   high_quality_article_count
# sub_region
# CARIBBEAN                                 13
# CENTRAL AMERICA                           23
# CENTRAL ASIA                               7
# EAST ASIA                                 76
# EASTERN AFRICA                            35
# EASTERN EUROPE                           118
# MIDDLE AFRICA                             16
# NORTHERN AFRICA                           19
# NORTHERN AMERICA                         104
# NORTHERN EUROPE                          102
# OCEANIA                                   63
# SOUTH AMERICA                             40
# SOUTH ASIA                                71
# SOUTHEAST ASIA                            73
# SOUTHERN AFRICA                            9
# SOUTHERN EUROPE                           74
# WESTERN AFRICA                            40
# WESTERN ASIA                              89
# WESTERN EUROPE                            56

# %%
region_population_temp= wpds_data_clean.loc[(wpds_data_clean['Type'].apply(lambda r: r == 'Sub-Region'))]
region_population = region_population_temp.rename(columns={'Population': 'population', 'Name': 'sub_region'})
region_population
# Out:
#                           sub_region        Type  population
# 1                             AFRICA  Sub-Region  1337918000
# 2                    NORTHERN AFRICA  Sub-Region   244344000
# 10                    WESTERN AFRICA  Sub-Region   401115000
# 27                    EASTERN AFRICA  Sub-Region   444970000
# 48                     MIDDLE AFRICA  Sub-Region   179757000
# 58                   SOUTHERN AFRICA  Sub-Region    67732000
# 64                  NORTHERN AMERICA  Sub-Region   368193000
# 67   LATIN AMERICA AND THE CARIBBEAN  Sub-Region   651036000
# 68                   CENTRAL AMERICA  Sub-Region   178611000
# 77                         CARIBBEAN  Sub-Region    43233000
# 95                     SOUTH AMERICA  Sub-Region   429191000
# 109                             ASIA  Sub-Region  4625927000
# 110                     WESTERN ASIA  Sub-Region   280927000
# 129                     CENTRAL ASIA  Sub-Region    74961000
# 135                       SOUTH ASIA  Sub-Region  1967131000
# 145                   SOUTHEAST ASIA  Sub-Region   661845000
# 157                        EAST ASIA  Sub-Region  1641063000
# 166                           EUROPE  Sub-Region   746622000
# 167                  NORTHERN EUROPE  Sub-Region   105990000
# 168                  Channel Islands  Sub-Region      172000
# 179                   WESTERN EUROPE  Sub-Region   195479000
# 189                   EASTERN EUROPE  Sub-Region   291902000
# 200                  SOUTHERN EUROPE  Sub-Region   153251000
# 216                          OCEANIA  Sub-Region    43155000

# %%
# join region level data
region_merged_aggregate_data_intermediate = region_article_count.merge(region_population,how='left',left_on=['sub_region'],right_on=['sub_region'])
region_merged_aggregate_data_intermediate
# Out:
#           sub_region  article_count        Type  population
# 0          CARIBBEAN            695  Sub-Region    43233000
# 1    CENTRAL AMERICA           1543  Sub-Region   178611000
# 2       CENTRAL ASIA            245  Sub-Region    74961000
# 3          EAST ASIA           2473  Sub-Region  1641063000
# 4     EASTERN AFRICA           2502  Sub-Region   444970000
# 5     EASTERN EUROPE           3732  Sub-Region   291902000
# 6      MIDDLE AFRICA            665  Sub-Region   179757000
# 7    NORTHERN AFRICA            899  Sub-Region   244344000
# 8   NORTHERN AMERICA           1901  Sub-Region   368193000
# 9    NORTHERN EUROPE           3763  Sub-Region   105990000
# 10           OCEANIA           3126  Sub-Region    43155000
# 11     SOUTH AMERICA           3032  Sub-Region   429191000
# 12        SOUTH ASIA           4366  Sub-Region  1967131000
# 13    SOUTHEAST ASIA           2020  Sub-Region   661845000
# 14   SOUTHERN AFRICA            634  Sub-Region    67732000
# 15   SOUTHERN EUROPE           3710  Sub-Region   153251000
# 16    WESTERN AFRICA           2139  Sub-Region   401115000
# 17      WESTERN ASIA           2563  Sub-Region   280927000
# 18    WESTERN EUROPE           4560  Sub-Region   195479000

# %%
region_merged_aggregate_data = region_merged_aggregate_data_intermediate.merge(region_high_quality_article_count,how='left',left_on=['sub_region'],right_on=['sub_region'])
region_merged_aggregate_data
# Out:
#           sub_region  article_count        Type  population  \
# 0          CARIBBEAN            695  Sub-Region    43233000
# 1    CENTRAL AMERICA           1543  Sub-Region   178611000
# 2       CENTRAL ASIA            245  Sub-Region    74961000
# 3          EAST ASIA           2473  Sub-Region  1641063000
# 4     EASTERN AFRICA           2502  Sub-Region   444970000
# 5     EASTERN EUROPE           3732  Sub-Region   291902000
# 6      MIDDLE AFRICA            665  Sub-Region   179757000
# 7    NORTHERN AFRICA            899  Sub-Region   244344000
# 8   NORTHERN AMERICA           1901  Sub-Region   368193000
# 9    NORTHERN EUROPE           3763  Sub-Region   105990000
# 10           OCEANIA           3126  Sub-Region    43155000
# 11     SOUTH AMERICA           3032  Sub-Region   429191000
# 12        SOUTH ASIA           4366  Sub-Region  1967131000
# 13    SOUTHEAST ASIA           2020  Sub-Region   661845000
# 14   SOUTHERN AFRICA            634  Sub-Region    67732000
# 15   SOUTHERN EUROPE           3710  Sub-Region   153251000
# 16    WESTERN AFRICA           2139  Sub-Region   401115000
# 17      WESTERN ASIA           2563  Sub-Region   280927000
# 18    WESTERN EUROPE           4560  Sub-Region   195479000
#
#     high_quality_article_count
# 0                           13
# 1                           23
# 2                            7
# 3                           76
# 4                           35
# 5                          118
# 6                           16
# 7                           19
# 8                          104
# 9                          102
# 10                          63
# 11                          40
# 12                          71
# 13                          73
# 14                           9
# 15                          74
# 16                          40
# 17                          89
# 18                          56

# %%
# Calculate the percentage for region level data
region_merged_aggregate_data['articles_per_population'] = region_merged_aggregate_data['article_count'].astype('int64')  / region_merged_aggregate_data['population'].astype('int64') * 100
region_merged_aggregate_data['high_quality_article_percentage'] = region_merged_aggregate_data['high_quality_article_count'].astype('int64')/ region_merged_aggregate_data['article_count'].astype('int64') * 100

region_merged_aggregate_data
# Out:
#           sub_region  article_count        Type  population  \
# 0          CARIBBEAN            695  Sub-Region    43233000
# 1    CENTRAL AMERICA           1543  Sub-Region   178611000
# 2       CENTRAL ASIA            245  Sub-Region    74961000
# 3          EAST ASIA           2473  Sub-Region  1641063000
# 4     EASTERN AFRICA           2502  Sub-Region   444970000
# 5     EASTERN EUROPE           3732  Sub-Region   291902000
# 6      MIDDLE AFRICA            665  Sub-Region   179757000
# 7    NORTHERN AFRICA            899  Sub-Region   244344000
# 8   NORTHERN AMERICA           1901  Sub-Region   368193000
# 9    NORTHERN EUROPE           3763  Sub-Region   105990000
# 10           OCEANIA           3126  Sub-Region    43155000
# 11     SOUTH AMERICA           3032  Sub-Region   429191000
# 12        SOUTH ASIA           4366  Sub-Region  1967131000
# 13    SOUTHEAST ASIA           2020  Sub-Region   661845000
# 14   SOUTHERN AFRICA            634  Sub-Region    67732000
# 15   SOUTHERN EUROPE           3710  Sub-Region   153251000
# 16    WESTERN AFRICA           2139  Sub-Region   401115000
# 17      WESTERN ASIA           2563  Sub-Region   280927000
# 18    WESTERN EUROPE           4560  Sub-Region   195479000
#
#     high_quality_article_count  articles_per_population  \
# 0                           13                 0.001608
# 1                           23                 0.000864
# 2                            7                 0.000327
# 3                           76                 0.000151
# 4                           35                 0.000562
# 5                          118                 0.001279
# 6                           16                 0.000370
# 7                           19                 0.000368
# 8                          104                 0.000516
# 9                          102                 0.003550
# 10                          63                 0.007244
# 11                          40                 0.000706
# 12                          71                 0.000222
# 13                          73                 0.000305
# 14                           9                 0.000936
# 15                          74                 0.002421
# 16                          40                 0.000533
# 17                          89                 0.000912
# 18                          56                 0.002333
#
#     high_quality_article_percentage
# 0                          1.870504
# 1                          1.490603
# 2                          2.857143
# 3                          3.073190
# 4                          1.398881
# 5                          3.161844
# 6                          2.406015
# 7                          2.113459
# 8                          5.470805
# 9                          2.710603
# 10                         2.015355
# 11                         1.319261
# 12                         1.626202
# 13                         3.613861
# 14                         1.419558
# 15                         1.994609
# 16                         1.870033
# 17                         3.472493
# 18                         1.228070

# %% [markdown]
# ## Step 6: Results
#
# + Top 10 countries by coverage: 10 highest-ranked countries in terms of number of politician articles as a proportion of country population
# + Bottom 10 countries by coverage: 10 lowest-ranked countries in terms of number of politician articles as a proportion of country population
# + Top 10 countries by relative quality: 10 highest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality
# + Bottom 10 countries by relative quality: 10 lowest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality
# + Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the total count of politician articles from countries in each region as a proportion of total regional population
# + Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the relative proportion of politician articles from countries in each region that are of GA and FA-quality

# %%
# Top 10 countries by coverage: 10 highest-ranked countries in terms of number of politician articles as a proportion of country population
country_merged_aggregate_data.sort_values('articles_per_population', ascending=False).head(10)
# Out:
#                                 article_count  population  \
# country
# Tuvalu                                     54     10000.0
# Nauru                                      52     11000.0
# San Marino                                 81     34000.0
# Monaco                                     40     38000.0
# Liechtenstein                              28     39000.0
# Marshall Islands                           37     57000.0
# Tonga                                      63     99000.0
# Iceland                                   201    368000.0
# Andorra                                    34     82000.0
# Federated States of Micronesia             36    106000.0
#
#                                 high_quality_article_count  \
# country
# Tuvalu                                                 4.0
# Nauru                                                  0.0
# San Marino                                             0.0
# Monaco                                                 0.0
# Liechtenstein                                          0.0
# Marshall Islands                                       0.0
# Tonga                                                  0.0
# Iceland                                                2.0
# Andorra                                                0.0
# Federated States of Micronesia                         0.0
#
#                                 articles_per_population  \
# country
# Tuvalu                                         0.540000
# Nauru                                          0.472727
# San Marino                                     0.238235
# Monaco                                         0.105263
# Liechtenstein                                  0.071795
# Marshall Islands                               0.064912
# Tonga                                          0.063636
# Iceland                                        0.054620
# Andorra                                        0.041463
# Federated States of Micronesia                 0.033962
#
#                                 high_quality_article_percentage
# country
# Tuvalu                                                 7.407407
# Nauru                                                  0.000000
# San Marino                                             0.000000
# Monaco                                                 0.000000
# Liechtenstein                                          0.000000
# Marshall Islands                                       0.000000
# Tonga                                                  0.000000
# Iceland                                                0.995025
# Andorra                                                0.000000
# Federated States of Micronesia                         0.000000

# %%
# Bottom 10 countries by coverage: 10 lowest-ranked countries in terms of number of politician articles as a proportion of country population

country_merged_aggregate_data.sort_values('articles_per_population', ascending=True).head(10)
# Out:
#               article_count    population  high_quality_article_count  \
# country
# India                   968  1.400100e+09                        13.0
# Indonesia               209  2.717390e+08                         9.0
# China                  1129  1.402385e+09                        40.0
# Uzbekistan               28  3.417400e+07                         3.0
# Ethiopia                101  1.149160e+08                         2.0
# Zambia                   25  1.838400e+07                         0.0
# Korea, North             36  2.577900e+07                         8.0
# Thailand                112  6.653400e+07                         3.0
# Mozambique               58  3.116600e+07                         0.0
# Bangladesh              317  1.698090e+08                         3.0
#
#               articles_per_population  high_quality_article_percentage
# country
# India                        0.000069                         1.342975
# Indonesia                    0.000077                         4.306220
# China                        0.000081                         3.542958
# Uzbekistan                   0.000082                        10.714286
# Ethiopia                     0.000088                         1.980198
# Zambia                       0.000136                         0.000000
# Korea, North                 0.000140                        22.222222
# Thailand                     0.000168                         2.678571
# Mozambique                   0.000186                         0.000000
# Bangladesh                   0.000187                         0.946372

# %%
# Top 10 countries by relative quality: 10 highest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality
country_merged_aggregate_data.sort_values('high_quality_article_percentage', ascending=False).head(10)
# Out:
#                           article_count  population  \
# country
# Korea, North                         36  25779000.0
# Saudi Arabia                        117  35041000.0
# Romania                             343  19241000.0
# Central African Republic             66   4830000.0
# Uzbekistan                           28  34174000.0
# Mauritania                           48   4650000.0
# Guatemala                            83  18066000.0
# Dominica                             12     72000.0
# Syria                               128  19398000.0
# Benin                                91  12209000.0
#
#                           high_quality_article_count  articles_per_population  \
# country
# Korea, North                                     8.0                 0.000140
# Saudi Arabia                                    15.0                 0.000334
# Romania                                         42.0                 0.001783
# Central African Republic                         8.0                 0.001366
# Uzbekistan                                       3.0                 0.000082
# Mauritania                                       5.0                 0.001032
# Guatemala                                        7.0                 0.000459
# Dominica                                         1.0                 0.016667
# Syria                                           10.0                 0.000660
# Benin                                            7.0                 0.000745
#
#                           high_quality_article_percentage
# country
# Korea, North                                    22.222222
# Saudi Arabia                                    12.820513
# Romania                                         12.244898
# Central African Republic                        12.121212
# Uzbekistan                                      10.714286
# Mauritania                                      10.416667
# Guatemala                                        8.433735
# Dominica                                         8.333333
# Syria                                            7.812500
# Benin                                            7.692308

# %%
# Bottom 10 countries by relative quality: 10 lowest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality
country_merged_aggregate_data.sort_values('high_quality_article_percentage', ascending=True).head(10)
# Out:
#                  article_count  population  high_quality_article_count  \
# country
# Solomon Islands             97    715000.0                         0.0
# Tonga                       63     99000.0                         0.0
# Nauru                       52     11000.0                         0.0
# Namibia                    162   2541000.0                         0.0
# Djibouti                    37    988000.0                         0.0
# Mozambique                  58  31166000.0                         0.0
# Monaco                      40     38000.0                         0.0
# Eritrea                     16   3546000.0                         0.0
# Estonia                    148   1331000.0                         0.0
# Moldova                    421   3535000.0                         0.0
#
#                  articles_per_population  high_quality_article_percentage
# country
# Solomon Islands                 0.013566                              0.0
# Tonga                           0.063636                              0.0
# Nauru                           0.472727                              0.0
# Namibia                         0.006375                              0.0
# Djibouti                        0.003745                              0.0
# Mozambique                      0.000186                              0.0
# Monaco                          0.105263                              0.0
# Eritrea                         0.000451                              0.0
# Estonia                         0.011119                              0.0
# Moldova                         0.011909                              0.0

# %%
# Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the total count of politician articles from countries in each region as a proportion of total regional population

region_merged_aggregate_data.sort_values('articles_per_population', ascending=False)
# Out:
#           sub_region  article_count        Type  population  \
# 10           OCEANIA           3126  Sub-Region    43155000
# 9    NORTHERN EUROPE           3763  Sub-Region   105990000
# 15   SOUTHERN EUROPE           3710  Sub-Region   153251000
# 18    WESTERN EUROPE           4560  Sub-Region   195479000
# 0          CARIBBEAN            695  Sub-Region    43233000
# 5     EASTERN EUROPE           3732  Sub-Region   291902000
# 14   SOUTHERN AFRICA            634  Sub-Region    67732000
# 17      WESTERN ASIA           2563  Sub-Region   280927000
# 1    CENTRAL AMERICA           1543  Sub-Region   178611000
# 11     SOUTH AMERICA           3032  Sub-Region   429191000
# 4     EASTERN AFRICA           2502  Sub-Region   444970000
# 16    WESTERN AFRICA           2139  Sub-Region   401115000
# 8   NORTHERN AMERICA           1901  Sub-Region   368193000
# 6      MIDDLE AFRICA            665  Sub-Region   179757000
# 7    NORTHERN AFRICA            899  Sub-Region   244344000
# 2       CENTRAL ASIA            245  Sub-Region    74961000
# 13    SOUTHEAST ASIA           2020  Sub-Region   661845000
# 12        SOUTH ASIA           4366  Sub-Region  1967131000
# 3          EAST ASIA           2473  Sub-Region  1641063000
#
#     high_quality_article_count  articles_per_population  \
# 10                          63                 0.007244
# 9                          102                 0.003550
# 15                          74                 0.002421
# 18                          56                 0.002333
# 0                           13                 0.001608
# 5                          118                 0.001279
# 14                           9                 0.000936
# 17                          89                 0.000912
# 1                           23                 0.000864
# 11                          40                 0.000706
# 4                           35                 0.000562
# 16                          40                 0.000533
# 8                          104                 0.000516
# 6                           16                 0.000370
# 7                           19                 0.000368
# 2                            7                 0.000327
# 13                          73                 0.000305
# 12                          71                 0.000222
# 3                           76                 0.000151
#
#     high_quality_article_percentage
# 10                         2.015355
# 9                          2.710603
# 15                         1.994609
# 18                         1.228070
# 0                          1.870504
# 5                          3.161844
# 14                         1.419558
# 17                         3.472493
# 1                          1.490603
# 11                         1.319261
# 4                          1.398881
# 16                         1.870033
# 8                          5.470805
# 6                          2.406015
# 7                          2.113459
# 2                          2.857143
# 13                         3.613861
# 12                         1.626202
# 3                          3.073190

# %%
# Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the relative proportion of politician articles from countries in each region that are of GA and FA-quality
region_merged_aggregate_data.sort_values('high_quality_article_percentage', ascending=False)
# Out:
#           sub_region  article_count        Type  population  \
# 8   NORTHERN AMERICA           1901  Sub-Region   368193000
# 13    SOUTHEAST ASIA           2020  Sub-Region   661845000
# 17      WESTERN ASIA           2563  Sub-Region   280927000
# 5     EASTERN EUROPE           3732  Sub-Region   291902000
# 3          EAST ASIA           2473  Sub-Region  1641063000
# 2       CENTRAL ASIA            245  Sub-Region    74961000
# 9    NORTHERN EUROPE           3763  Sub-Region   105990000
# 6      MIDDLE AFRICA            665  Sub-Region   179757000
# 7    NORTHERN AFRICA            899  Sub-Region   244344000
# 10           OCEANIA           3126  Sub-Region    43155000
# 15   SOUTHERN EUROPE           3710  Sub-Region   153251000
# 0          CARIBBEAN            695  Sub-Region    43233000
# 16    WESTERN AFRICA           2139  Sub-Region   401115000
# 12        SOUTH ASIA           4366  Sub-Region  1967131000
# 1    CENTRAL AMERICA           1543  Sub-Region   178611000
# 14   SOUTHERN AFRICA            634  Sub-Region    67732000
# 4     EASTERN AFRICA           2502  Sub-Region   444970000
# 11     SOUTH AMERICA           3032  Sub-Region   429191000
# 18    WESTERN EUROPE           4560  Sub-Region   195479000
#
#     high_quality_article_count  articles_per_population  \
# 8                          104                 0.000516
# 13                          73                 0.000305
# 17                          89                 0.000912
# 5                          118                 0.001279
# 3                           76                 0.000151
# 2                            7                 0.000327
# 9                          102                 0.003550
# 6                           16                 0.000370
# 7                           19                 0.000368
# 10                          63                 0.007244
# 15                          74                 0.002421
# 0                           13                 0.001608
# 16                          40                 0.000533
# 12                          71                 0.000222
# 1                           23                 0.000864
# 14                           9                 0.000936
# 4                           35                 0.000562
# 11                          40                 0.000706
# 18                          56                 0.002333
#
#     high_quality_article_percentage
# 8                          5.470805
# 13                         3.613861
# 17                         3.472493
# 5                          3.161844
# 3                          3.073190
# 2                          2.857143
# 9                          2.710603
# 6                          2.406015
# 7                          2.113459
# 10                         2.015355
# 15                         1.994609
# 0                          1.870504
# 16                         1.870033
# 12                         1.626202
# 1                          1.490603
# 14                         1.419558
# 4                          1.398881
# 11                         1.319261
# 18                         1.228070
